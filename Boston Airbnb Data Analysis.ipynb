# %% [markdown]
# # Boston AirBNB Data

# %% [markdown]
# ### By: Shashwat Singh Mann

# %% [markdown]
# Importing necessary files

# %%
#importing files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
#Reading CSV files
calender = pd.read_csv("calendar.csv")
listings = pd.read_csv("listings.csv")
reviews = pd.read_csv("reviews.csv")

# %% [markdown]
# ## Exploring the Listing dataset

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
# id                                  3585 non-null int64
# listing_url                         3585 non-null object
# scrape_id                           3585 non-null int64
# last_scraped                        3585 non-null object
# name                                3585 non-null object
# summary                             3442 non-null object
# space                               2528 non-null object
# description                         3585 non-null object
# experiences_offered                 3585 non-null object
# neighborhood_overview               2170 non-null object
# notes                               1610 non-null object
# transit                             2295 non-null object
# access                              2096 non-null object
# interaction                         2031 non-null object
# house_rules                         2393 non-null object
# thumbnail_url                       2986 non-null object
# medium_url                          2986 non-null object
# picture_url                         3585 non-null object
# xl_picture_url                      2986 non-null object
# host_id                             3585 non-null int64
# host_url                            3585 non-null object
# host_name                           3585 non-null object
# host_since                          3585 non-null object
# host_location                       3574 non-null object
# host_about                          2276 non-null object
# host_response_time                  3114 non-null object
# host_response_rate                  3114 non-null object
# host_acceptance_rate                3114 non-null object
# host_is_superhost                   3585 non-null object
# host_thumbnail_url                  3585 non-null object
# host_picture_url                    3585 non-null object
# host_neighbourhood                  3246 non-null object
# host_listings_count                 3585 non-null int64
# host_total_listings_count           3585 non-null int64
# host_verifications                  3585 non-null object
# host_has_profile_pic                3585 non-null object
# host_identity_verified              3585 non-null object
# street                              3585 non-null object
# neighbourhood                       3042 non-null object
# neighbourhood_cleansed              3585 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                3583 non-null object
# state                               3585 non-null object
# zipcode                             3547 non-null object
# market                              3571 non-null object
# smart_location                      3585 non-null object
# country_code                        3585 non-null object
# country                             3585 non-null object
# latitude                            3585 non-null float64
# longitude                           3585 non-null float64
# is_location_exact                   3585 non-null object
# property_type                       3582 non-null object
# room_type                           3585 non-null object
# accommodates                        3585 non-null int64
# bathrooms                           3571 non-null float64
# bedrooms                            3575 non-null float64
# beds                                3576 non-null float64
# bed_type                            3585 non-null object
# amenities                           3585 non-null object
# square_feet                         56 non-null float64
# price                               3585 non-null object
# weekly_price                        892 non-null object
# monthly_price                       888 non-null object
# security_deposit                    1342 non-null object
# cleaning_fee                        2478 non-null object
# guests_included                     3585 non-null int64
# extra_people                        3585 non-null object
# minimum_nights                      3585 non-null int64
# maximum_nights                      3585 non-null int64
# calendar_updated                    3585 non-null object
# has_availability                    0 non-null float64
# availability_30                     3585 non-null int64
# availability_60                     3585 non-null int64
# availability_90                     3585 non-null int64
# availability_365                    3585 non-null int64
# calendar_last_scraped               3585 non-null object
# number_of_reviews                   3585 non-null int64
# first_review                        2829 non-null object
# last_review                         2829 non-null object
# review_scores_rating                2772 non-null float64
# review_scores_accuracy              2762 non-null float64
# review_scores_cleanliness           2767 non-null float64
# review_scores_checkin               2765 non-null float64
# review_scores_communication         2767 non-null float64
# review_scores_location              2763 non-null float64
# review_scores_value                 2764 non-null float64
# requires_license                    3585 non-null object
# license                             0 non-null float64
# jurisdiction_names                  0 non-null float64
# instant_bookable                    3585 non-null object
# cancellation_policy                 3585 non-null object
# require_guest_profile_picture       3585 non-null object
# require_guest_phone_verification    3585 non-null object
# calculated_host_listings_count      3585 non-null int64
# reviews_per_month                   2829 non-null float64
# dtypes: float64(18), int64(15), object(62)
# memory usage: 2.6+ MB

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03  3.585000e+03          3585.000000
# mean   8.440875e+06  2.016091e+13  2.492311e+07            58.902371
# std    4.500787e+06  8.516813e-01  2.292781e+07           171.119663
# min    3.353000e+03  2.016091e+13  4.240000e+03             0.000000
# 25%    4.679319e+06  2.016091e+13  6.103425e+06             1.000000
# 50%    8.577620e+06  2.016091e+13  1.928100e+07             2.000000
# 75%    1.278953e+07  2.016091e+13  3.622147e+07             7.000000
# max    1.493346e+07  2.016091e+13  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# min                     0.000000                           NaN    42.235942
# 25%                     1.000000                           NaN    42.329995
# 50%                     2.000000                           NaN    42.345201
# 75%                     7.000000                           NaN    42.354685
# max                   749.000000                           NaN    42.389982
#
#          longitude  accommodates    bathrooms  ...  review_scores_accuracy  \
# count  3585.000000   3585.000000  3571.000000  ...             2762.000000
# mean    -71.084818      3.041283     1.221647  ...                9.431571
# std       0.031565      1.778929     0.501487  ...                0.931863
# min     -71.171789      1.000000     0.000000  ...                2.000000
# 25%     -71.105083      2.000000     1.000000  ...                9.000000
# 50%     -71.078429      2.000000     1.000000  ...               10.000000
# 75%     -71.062155      4.000000     1.000000  ...               10.000000
# max     -71.000100     16.000000     6.000000  ...               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                2767.000000            2765.000000
# mean                    9.258041               9.646293
# std                     1.168977               0.762753
# min                     2.000000               2.000000
# 25%                     9.000000               9.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  2767.000000             2763.000000
# mean                      9.646549                9.414043
# std                       0.735507                0.903436
# min                       4.000000                2.000000
# 25%                       9.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  license  jurisdiction_names  \
# count          2764.000000      0.0                 0.0
# mean              9.168234      NaN                 NaN
# std               1.011116      NaN                 NaN
# min               2.000000      NaN                 NaN
# 25%               9.000000      NaN                 NaN
# 50%               9.000000      NaN                 NaN
# 75%              10.000000      NaN                 NaN
# max              10.000000      NaN                 NaN
#
#        calculated_host_listings_count  reviews_per_month
# count                     3585.000000        2829.000000
# mean                        12.733891           1.970908
# std                         29.415076           2.120561
# min                          1.000000           0.010000
# 25%                          1.000000           0.480000
# 50%                          2.000000           1.170000
# 75%                          6.000000           2.720000
# max                        136.000000          19.150000
#
# [8 rows x 33 columns]

# %%
# dropping values which has NaN
listings.dropna(subset=["review_scores_rating", "price", "review_scores_value", "neighbourhood", 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'property_type'], axis = 0, inplace = True)

# %%
listings.drop(["jurisdiction_names", "license", "has_availability", "square_feet", "neighbourhood_group_cleansed"], axis = 1, inplace = True)

# %%
listings.sample(5)
# Out:
#             id                            listing_url       scrape_id  \
# 795   12351909  https://www.airbnb.com/rooms/12351909  20160906204935
# 3286   4261784   https://www.airbnb.com/rooms/4261784  20160906204935
# 1323  14711359  https://www.airbnb.com/rooms/14711359  20160906204935
# 3024   3294152   https://www.airbnb.com/rooms/3294152  20160906204935
# 3313   7283351   https://www.airbnb.com/rooms/7283351  20160906204935
#
#      last_scraped                                             name  \
# 795    2016-09-07                    Freshly Renovated Studio by T
# 3286   2016-09-07              Big room steps to BCEC conv center!
# 1323   2016-09-07  Best location in Boston (Back Bay) opposite MIT
# 3024   2016-09-07              Garden apartment near subway, beach
# 3313   2016-09-07                Private room, steps to green line
#
#                                                 summary  \
# 795   Freshly renovated studio apartment with new fl...
# 3286  1 spacious bedroom with porch access in my 2 b...
# 1323  My place is close to Back Bay, MIT, Boston Pub...
# 3024  Delicously cool one-bedroom apartment opens on...
# 3313  It is sunny and clean, one bedroon in a two be...
#
#                                                   space  \
# 795   The kitchen has a two burner cooktop, microwav...
# 3286  I have a large outdoor space to enjoy during t...
# 1323                                                NaN
# 3024  You enter via a new deck with table and chairs...
# 3313  It is sunny and clean, one bedroon in a two be...
#
#                                             description experiences_offered  \
# 795   Freshly renovated studio apartment with new fl...                none
# 3286  1 spacious bedroom with porch access in my 2 b...                none
# 1323  My place is close to Back Bay, MIT, Boston Pub...                none
# 3024  Delicously cool one-bedroom apartment opens on...                none
# 3313  It is sunny and clean, one bedroon in a two be...                none
#
#                                   neighborhood_overview  ...  \
# 795   It's pretty residential on the street, but pla...  ...
# 3286               Clean and safe, and super convenient  ...
# 1323                                                NaN  ...
# 3024  Jones Hill is a quiet, safe residential neighb...  ...
# 3313                                                NaN  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 795                         10.0                    9.0                10.0
# 3286                         9.0                    9.0                 9.0
# 1323                        10.0                   10.0                 9.0
# 3024                        10.0                    9.0                 9.0
# 3313                        10.0                    9.0                10.0
#
#      requires_license instant_bookable cancellation_policy  \
# 795                 f                f            moderate
# 3286                f                f              strict
# 1323                f                f              strict
# 3024                f                f            moderate
# 3313                f                f            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 795                              f                                f
# 3286                             f                                f
# 1323                             f                                f
# 3024                             f                                f
# 3313                             f                                f
#
#      calculated_host_listings_count  reviews_per_month
# 795                               2               4.50
# 3286                              2               0.20
# 1323                              1               2.00
# 3024                              4               2.89
# 3313                              1               0.37
#
# [5 rows x 90 columns]

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'calendar_updated',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
listings.sample(2)
# Out:
#            id                           listing_url       scrape_id  \
# 311   5182313  https://www.airbnb.com/rooms/5182313  20160906204935
# 2014  9274587  https://www.airbnb.com/rooms/9274587  20160906204935
#
#      last_scraped                               name  \
# 311    2016-09-07   Sunny musicians apt. close to T!
# 2014   2016-09-07  Spectacular Beacon Hill 1 bedroom
#
#                                                 summary  \
# 311   Welcome to our home! We (Rachel and Adam) live...
# 2014  Charles Street is one of the most popular stre...
#
#                                                   space  \
# 311   The space is ideal for solo travelers or coupl...
# 2014  This one bedroom suite features a full-sized k...
#
#                                             description experiences_offered  \
# 311   Welcome to our home! We (Rachel and Adam) live...                none
# 2014  Charles Street is one of the most popular stre...                none
#
#                                   neighborhood_overview  \
# 311   Some call it the Brooklyn of Boston, Jamaica P...
# 2014  Charles Street is one of the most popular stre...
#
#                                                   notes  \
# 311   A/C is installed in your room for the summer S...
# 2014  Every floor has elevator access and although t...
#
#                                                 transit  \
# 311   Situated in Egelston Square, we are just a 5-7...
# 2014  This location is very central and it’s easy to...
#
#                                                  access  \
# 311   Linens and Towels provided, and a hairdryer is...
# 2014  Guests have access to their unit and the commo...
#
#                                             interaction  \
# 311   One of us will be available to meet you and we...
# 2014  We have prepared for your stay so that it requ...
#
#                                             house_rules  \
# 311   No drugs, no smoking, no pets (our dog is enou...
# 2014                     No pets. No smoking. Please :)
#
#                                           thumbnail_url  \
# 311   https://a2.muscache.com/im/pictures/72657685/7...
# 2014                                                NaN
#
#                                              medium_url  \
# 311   https://a2.muscache.com/im/pictures/72657685/7...
# 2014                                                NaN
#
#                                             picture_url  \
# 311   https://a2.muscache.com/im/pictures/72657685/7...
# 2014  https://a2.muscache.com/im/pictures/c1de2ac3-3...
#
#                                          xl_picture_url  host_id  \
# 311   https://a2.muscache.com/im/pictures/72657685/7...   548184
# 2014                                                NaN  1444340
#
#                                        host_url        host_name  host_since  \
# 311    https://www.airbnb.com/users/show/548184  Adam And Rachel  2011-05-01
# 2014  https://www.airbnb.com/users/show/1444340             Will  2011-11-26
#
#                              host_location  \
# 311   Boston, Massachusetts, United States
# 2014  Boston, Massachusetts, United States
#
#                                              host_about  host_response_time  \
# 311   We are a recently married couple that moved to...  within a few hours
# 2014  Originally from Los Angeles, my wife and I hav...        within a day
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 311                100%                  85%                 t
# 2014                98%                  68%                 f
#
#                                      host_thumbnail_url  \
# 311   https://a0.muscache.com/im/users/548184/profil...
# 2014  https://a1.muscache.com/im/users/1444340/profi...
#
#                                        host_picture_url host_neighbourhood  \
# 311   https://a0.muscache.com/im/users/548184/profil...      Jamaica Plain
# 2014  https://a1.muscache.com/im/users/1444340/profi...            Roxbury
#
#       host_listings_count  host_total_listings_count  \
# 311                     1                          1
# 2014                   24                         24
#
#                                     host_verifications host_has_profile_pic  \
# 311   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2014              ['email', 'phone', 'reviews', 'kba']                    t
#
#      host_identity_verified                                            street  \
# 311                       t  Atherton Street, Boston, MA 02119, United States
# 2014                      t   Charles Street, Boston, MA 02114, United States
#
#       neighbourhood neighbourhood_cleansed    city state zipcode  market  \
# 311   Jamaica Plain          Jamaica Plain  Boston    MA   02119  Boston
# 2014    Beacon Hill            Beacon Hill  Boston    MA   02114  Boston
#
#      smart_location country_code        country   latitude  longitude  \
# 311      Boston, MA           US  United States  42.315478 -71.099294
# 2014     Boston, MA           US  United States  42.357559 -71.071720
#
#      is_location_exact property_type        room_type  accommodates  \
# 311                  t     Apartment     Private room             2
# 2014                 t     Apartment  Entire home/apt             4
#
#       bathrooms  bedrooms  beds  bed_type  \
# 311         1.0       1.0   1.0  Real Bed
# 2014        1.0       1.0   1.0  Real Bed
#
#                                               amenities    price weekly_price  \
# 311   {Internet,"Wireless Internet","Air Conditionin...  $110.00          NaN
# 2014  {TV,"Cable TV",Internet,"Wireless Internet","A...  $229.00          NaN
#
#      monthly_price security_deposit cleaning_fee  guests_included  \
# 311            NaN              NaN        $5.00                1
# 2014           NaN          $500.00      $100.00                1
#
#      extra_people  minimum_nights  maximum_nights calendar_updated  \
# 311        $10.00               2               7       2 days ago
# 2014        $0.00               2            1125       1 week ago
#
#       availability_30  availability_60  availability_90  availability_365  \
# 311                12               42               72                72
# 2014                3               19               49               313
#
#      calendar_last_scraped  number_of_reviews first_review last_review  \
# 311             2016-09-06                 68   2015-03-14  2016-08-12
# 2014            2016-09-06                  9   2015-11-20  2016-08-05
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 311                   96.0                    10.0                        9.0
# 2014                  89.0                    10.0                        9.0
#
#       review_scores_checkin  review_scores_communication  \
# 311                    10.0                         10.0
# 2014                    9.0                          9.0
#
#       review_scores_location  review_scores_value requires_license  \
# 311                      9.0                 10.0                f
# 2014                    10.0                  9.0                f
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 311                 f            moderate                             t
# 2014                f              strict                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 311                                 t                               1
# 2014                                f                              24
#
#       reviews_per_month
# 311                3.75
# 2014               0.92

# %% [markdown]
# ## Wrangling and Cleaning Listings Data

# %%
# choosing columns which are important to us in this project
cols = ['id', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'property_type', 'accommodates', 'bathrooms', 'beds', 'price', 'review_scores_value', 'review_scores_rating', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_location', 'neighbourhood']

# %%
listings = listings[cols]
listings.head()
# Out:
#          id  host_response_time host_response_rate host_acceptance_rate  \
# 1   3075044      within an hour               100%                 100%
# 2      6976  within a few hours               100%                  88%
# 4   7651065      within an hour               100%                 100%
# 5  12386020  within a few hours               100%                  95%
# 7   2843445  within a few hours               100%                 100%
#
#   property_type  accommodates  bathrooms  beds   price  review_scores_value  \
# 1     Apartment             2        1.0   1.0  $65.00                  9.0
# 2     Apartment             2        1.0   1.0  $65.00                 10.0
# 4         House             2        1.5   2.0  $79.00                 10.0
# 5   Condominium             2        1.0   1.0  $75.00                 10.0
# 7         House             2        2.0   1.0  $75.00                 10.0
#
#    review_scores_rating  review_scores_cleanliness  \
# 1                  94.0                        9.0
# 2                  98.0                        9.0
# 4                  99.0                       10.0
# 5                 100.0                       10.0
# 7                  96.0                       10.0
#
#    review_scores_communication  review_scores_location neighbourhood
# 1                         10.0                     9.0    Roslindale
# 2                         10.0                     9.0    Roslindale
# 4                         10.0                     9.0    Roslindale
# 5                         10.0                     9.0    Roslindale
# 7                         10.0                    10.0    Roslindale

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
listings['price']=listings['price'].apply(wrangle_prices)
listings['price'] = pd.to_numeric(listings['price'])
# converting the prices to numeric value
listings.head()
# Out:
#          id  host_response_time host_response_rate host_acceptance_rate  \
# 1   3075044      within an hour               100%                 100%
# 2      6976  within a few hours               100%                  88%
# 4   7651065      within an hour               100%                 100%
# 5  12386020  within a few hours               100%                  95%
# 7   2843445  within a few hours               100%                 100%
#
#   property_type  accommodates  bathrooms  beds  price  review_scores_value  \
# 1     Apartment             2        1.0   1.0     65                  9.0
# 2     Apartment             2        1.0   1.0     65                 10.0
# 4         House             2        1.5   2.0     79                 10.0
# 5   Condominium             2        1.0   1.0     75                 10.0
# 7         House             2        2.0   1.0     75                 10.0
#
#    review_scores_rating  review_scores_cleanliness  \
# 1                  94.0                        9.0
# 2                  98.0                        9.0
# 4                  99.0                       10.0
# 5                 100.0                       10.0
# 7                  96.0                       10.0
#
#    review_scores_communication  review_scores_location neighbourhood
# 1                         10.0                     9.0    Roslindale
# 2                         10.0                     9.0    Roslindale
# 4                         10.0                     9.0    Roslindale
# 5                         10.0                     9.0    Roslindale
# 7                         10.0                    10.0    Roslindale

# %%
# removing % sign and converting host_response_rate to numeric
wrangle_data = lambda x : (x.replace('%',''))
listings['host_response_rate']=listings['host_response_rate'].apply(wrangle_data)
listings['host_response_rate'] = pd.to_numeric(listings['host_response_rate'])
listings['host_response_rate'].head()
# Out:
# 1    100
# 2    100
# 4    100
# 5    100
# 7    100
# Name: host_response_rate, dtype: int64

# %%
# removing % sign and converting it to numeric
wrangle_data = lambda x : (x.replace('%',''))
listings['host_acceptance_rate']=listings['host_acceptance_rate'].apply(wrangle_data)
listings['host_acceptance_rate'] = pd.to_numeric(listings['host_acceptance_rate'])
listings['host_acceptance_rate'].head()
# Out:
# 1    100
# 2     88
# 4    100
# 5     95
# 7    100
# Name: host_acceptance_rate, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 1 to 3583
# Data columns (total 15 columns):
# id                             2160 non-null int64
# host_response_time             2160 non-null object
# host_response_rate             2160 non-null int64
# host_acceptance_rate           2160 non-null int64
# property_type                  2160 non-null object
# accommodates                   2160 non-null int64
# bathrooms                      2150 non-null float64
# beds                           2158 non-null float64
# price                          2160 non-null int64
# review_scores_value            2160 non-null float64
# review_scores_rating           2160 non-null float64
# review_scores_cleanliness      2159 non-null float64
# review_scores_communication    2159 non-null float64
# review_scores_location         2159 non-null float64
# neighbourhood                  2160 non-null object
# dtypes: float64(7), int64(5), object(3)
# memory usage: 270.0+ KB

# %% [markdown]
# ## Wrangling and Cleaning Calendar Data

# %%
calender.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308890 entries, 0 to 1308889
# Data columns (total 4 columns):
# listing_id    1308890 non-null int64
# date          1308890 non-null object
# available     1308890 non-null object
# price         643037 non-null object
# dtypes: int64(1), object(3)
# memory usage: 39.9+ MB

# %%
calender.price.isnull().sum()/calender.shape[0]
# Out:
# 0.5087157820748879

# %%
calender.dropna(subset=['price'],axis=0,inplace=True)
calender.price.astype(str)
calender['date']= pd.to_datetime(calender['date'])

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
calender.price=calender.price.apply(wrangle_prices)
calender['price'].head()
# Out:
# 365    65
# 366    65
# 367    65
# 368    75
# 369    75
# Name: price, dtype: object

# %%
calender.head()
# Out:
#      listing_id       date available price
# 365     3075044 2017-08-22         t    65
# 366     3075044 2017-08-21         t    65
# 367     3075044 2017-08-20         t    65
# 368     3075044 2017-08-19         t    75
# 369     3075044 2017-08-18         t    75

# %%
calender['listing_id'] =calender['listing_id'].astype(str)

# %%
calender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 643037 entries, 365 to 1308879
# Data columns (total 4 columns):
# listing_id    643037 non-null object
# date          643037 non-null datetime64[ns]
# available     643037 non-null object
# price         643037 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 24.5+ MB

# %%
calender.describe()
# Out:
#        listing_id                 date available   price
# count      643037               643037    643037  643037
# unique       2906                  365         1    1246
# top      14421692  2016-12-04 00:00:00         t     150
# freq          365                 2207    643037   20752
# first         NaN  2016-09-06 00:00:00       NaN     NaN
# last          NaN  2017-09-05 00:00:00       NaN     NaN

# %% [markdown]
# Yeah, I did notice that I've spelled "Calendar" incorrectly

# %% [markdown]
# ## Wrangling and Cleaning Reviews Dataset

# %%
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
# listing_id       68275 non-null int64
# id               68275 non-null int64
# date             68275 non-null object
# reviewer_id      68275 non-null int64
# reviewer_name    68275 non-null object
# comments         68222 non-null object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB

# %%
reviews.describe()
# Out:
#          listing_id            id   reviewer_id
# count  6.827500e+04  6.827500e+04  6.827500e+04
# mean   4.759910e+06  5.246516e+07  2.802389e+07
# std    3.788990e+06  2.790991e+07  2.234097e+07
# min    3.353000e+03  1.021000e+03  1.430000e+02
# 25%    1.458081e+06  3.010420e+07  9.001346e+06
# 50%    4.080000e+06  5.223121e+07  2.305179e+07
# 75%    7.377034e+06  7.663248e+07  4.213454e+07
# max    1.484378e+07  9.999045e+07  9.335034e+07

# %% [markdown]
# Yeah, just felt that there wasn't much to do in this data set

# %% [markdown]
# ## Visualization

# %%
listings.head()
# Out:
#          id  host_response_time  host_response_rate  host_acceptance_rate  \
# 1   3075044      within an hour                 100                   100
# 2      6976  within a few hours                 100                    88
# 4   7651065      within an hour                 100                   100
# 5  12386020  within a few hours                 100                    95
# 7   2843445  within a few hours                 100                   100
#
#   property_type  accommodates  bathrooms  beds  price  review_scores_value  \
# 1     Apartment             2        1.0   1.0     65                  9.0
# 2     Apartment             2        1.0   1.0     65                 10.0
# 4         House             2        1.5   2.0     79                 10.0
# 5   Condominium             2        1.0   1.0     75                 10.0
# 7         House             2        2.0   1.0     75                 10.0
#
#    review_scores_rating  review_scores_cleanliness  \
# 1                  94.0                        9.0
# 2                  98.0                        9.0
# 4                  99.0                       10.0
# 5                 100.0                       10.0
# 7                  96.0                       10.0
#
#    review_scores_communication  review_scores_location neighbourhood
# 1                         10.0                     9.0    Roslindale
# 2                         10.0                     9.0    Roslindale
# 4                         10.0                     9.0    Roslindale
# 5                         10.0                     9.0    Roslindale
# 7                         10.0                    10.0    Roslindale

# %% [markdown]
# ### Finding a correlation between number of beds, accommodates and price

# %%
# Boxplots about accommodates, beds and price
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.boxplot(x='accommodates', y='price', data=listings)
plt.xlabel(xlabel='Accommodates', fontsize=15)
plt.ylabel(ylabel='Price', fontsize=15)

plt.subplot(1,2,2)
sns.boxplot(x='beds', y='price', data=listings)
plt.xlabel(xlabel='Beds', fontsize=15)
plt.ylabel(ylabel='Price', fontsize=15);

# %% [markdown]
# ### Finding the total counts of rents in each month

# %%
plt.figure(figsize=(14.70, 8.27))
calender['month'] = pd.to_datetime(calender['date']).dt.to_period('M') 
sns.countplot(data= calender, x= 'month')
plt.xlabel('Month',fontsize= 15)
plt.ylabel('Count',fontsize= 15);
plt.xticks(rotation=45); # rotating the text at x axis so that it's readable

# %% [markdown]
# It took 15 minutes and still the above cell was running when I tried to keep it in an order. So this is the reason I've kept it as it is.

# %% [markdown]
# ### User Satisfaction

# %%
# number of reviews based on scores
plt.figure(figsize=(14.70, 8.27))
sns.countplot(data= calender, x= listings['review_scores_value'])
plt.xlabel('Review Scores',fontsize= 15)
plt.ylabel('Count',fontsize= 15)
plt.xticks(rotation=45);

# %% [markdown]
# ### Price Based on Neighbourhood

# %%
# A function which would compare different variables with neighbourhood
def barchart(listings,column,sort_value):
    plt.figure(figsize=(20,10))
    plt.xticks(rotation=45)
    listings = listings.sort_values(by = sort_value)
    sns.barplot(x='neighbourhood', y=column, data = listings)
    plt.xlabel(xlabel='Neighbourhood', fontsize=18)
    plt.ylabel(ylabel=column, fontsize=18)

# %%
barchart(listings,'price','price')

# %% [markdown]
# ### Reviews Based on Neighbourhood

# %%
barchart(listings, 'review_scores_value', 'review_scores_value')

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='review_scores_value', y='price', data = listings)
plt.xlabel(xlabel='Review Scores', fontsize=18)
plt.ylabel(ylabel= 'Price', fontsize=18);

# %%
num_vars = ['price', 'review_scores_value', 'host_response_rate', 'host_acceptance_rate']
plt.figure(figsize = [50, 50])
g = sns.PairGrid(data = listings, vars = num_vars)
g.fig.subplots_adjust(hspace=.05, wspace=.05)
g.map_offdiag(plt.scatter)
plt.title('Matrix Plot');

# %% [markdown]
# The plot above shows the following:
# 1. A lot of them have a high host response rate which also shows its correlation with a high host acceptance rate
# 2. A high host response rate also gets you a higher chance of a higher review score
# 3. A high price also gives a higher chance of getting a higher review probably because either the place of rent is actually good or it could also be psychological
